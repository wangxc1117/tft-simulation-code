# %% [markdown]
# | Model                        | q-risk (P50, unscaled) |   RMSE |    MAE |
# |------------------------------|--------------------:|-------:|-------:|
# | OLS                          |            0.382020 | 0.6001 | 0.4745 |
# | VAR (1)                      |            0.377553 | 0.5939 | 0.4689 |
# | TFT                          |        **0.209972** | **0.3423** | **0.2607** |

# %% [markdown]
# | Model                         | q-risk (P50, unscaled) |   RMSE |    MAE |
# |------------------------------|--------------------:|-------:|-------:|
# | OLS (NO COV)                  |            0.421543 | 0.6354 | 0.5236 |
# | VAR (1) (NO COV)              |            0.353459 | 0.5359 | 0.4390 |
# | TFT (NO COV)                  |        **0.230519** | **0.3706** | **0.2863** |
