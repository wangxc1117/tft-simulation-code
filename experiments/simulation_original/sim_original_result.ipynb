# %% [markdown]
# | Scenario | noise_std | feature_noise_std | non_linear_strength | eta_rho | f_rho |
# | -------- | --------- | ----------------- | ------------------- | ------- | ----- |
# | A        | 0.3       | 0.0               | 0.0                 | 0.8     | 0.6   |
# | A′       | 0.3       | 0.0               | 0.0                 | 0.6     | 0.6   |
# | B        | 0.5       | 0.2               | 1.0                 | 0.8     | 0.6   |
# | B′       | 0.5       | 0.2               | 1.0                 | 0.6     | 0.6   |
# | C        | 0.5       | 0.2               | 2.0                 | 0.8     | 0.6   |
# | D        | 0.5       | 0.2               | 2.5                 | 0.4     | 0.6   |
# | E        | 0.5       | 0.2               | 2.5                 | 0.4     | 0.8   |

# %% [markdown]
# | Scenario | Model   | q-risk (P50, unscaled) |   RMSE(scaled) |    MAE(scaled) |
# | -------: | ------- | ---------------------: | -----: | -----: |
# |        A | OLS     |               0.014465 | 1.2517 | 0.9936 |
# |          | VAR (1) |               0.013992 | 1.2063 | 0.9611 |
# |          | TFT     |               0.015423 | 1.3268 | 1.0594 |
# |       A′ | OLS     |               0.014424 | 1.2511 | 0.9930 |
# |          | VAR (1) |               0.013906 | 1.2020 | 0.9573 |
# |          | TFT     |               0.015242 | 1.3151 | 1.0493 |
# |        B | OLS     |               0.079178 | 2.1255 | 1.4474 |
# |          | VAR (1) |               0.065903 | 1.7776 | 1.2048 |
# |          | TFT     |               0.084430 | 2.1924 | 1.5435 |
# |       B′ | OLS     |               0.079140 | 2.1257 | 1.4474 |
# |          | VAR (1) |               0.065879 | 1.7781 | 1.2049 |
# |          | TFT     |               0.084664 | 2.2020 | 1.5484 |
# |        C | OLS     |               0.146753 | 2.1303 | 1.4100 |
# |          | VAR (1) |               0.128992 | 1.8281 | 1.2373 |
# |          | TFT     |               0.162294 | 2.2432 | 1.5593 |
# |        D | OLS     |               0.168086 | 2.2277 | 1.4947 |
# |          | VAR (1) |               0.140047 | 1.8460 | 1.2454 |
# |          | TFT     |               0.179837 | 2.2825 | 1.5992 |
# | D (6000) | OLS     |               0.165735 | 2.2544 | 1.4948 |
# |          | VAR (1) |               0.088097 | 1.2755 | 0.7945 |
# |          | TFT     |               0.183067 | 2.3795 | 1.6511 |
# |        E | OLS     |               0.162469 | 2.1649 | 1.4438 |
# |          | VAR (1) |               0.088868 | 1.2282 | 0.7897 |
# |          | TFT     |               0.180229 | 2.2847 | 1.6016 |
