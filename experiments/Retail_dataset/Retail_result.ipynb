# %% [markdown]
# | Model                          | q-risk (P50, sales) |         RMSE |          MAE |
# | ------------------------------ | ------------------: | -----------: | -----------: |
# | **TFT (direct 30, with cov)**  |        **0.179594** | **0.116727** | **0.085391** |
# | TFT (direct 30, no future cov) |            0.321846 |     0.186304 |     0.145831 |
# | TFT (direct 30, no cov)        |            0.427365 |     0.217511 |     0.173511 |
# | OLS                            |            0.433589 |     0.278411 |     0.222790 |
# | OLS (no cov)                   |            0.362250 |     0.229836 |     0.175023 |
