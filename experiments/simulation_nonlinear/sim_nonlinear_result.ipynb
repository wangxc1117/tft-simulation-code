# %% [markdown]
# | noise_std | feature_noise_std | non_linear_strength | eta_rho | f_rho | y_rho | win |
# | --------- | ----------------- | ------------------- | ------- | ----- | ----- | --- |
# | 0.5       | 0.2               | 2.0                 | 0.8     | 0.6   | 0.85  | 50  |

# %% [markdown]
# y_gamma = 0.1 :
#
# | Model  | RMSE       | MAE        | P50 q-risk (scaled) | P50 q-risk (unscaled) |
# | ------ | ---------- | ---------- | ------------------- | --------------------- |
# | OLS    | 0.8124     | 0.5254     | 0.4837              | 0.2690                |
# | VAR(1) | 0.6957     | 0.5107     | 0.4701              | 0.2614                |
# | TFT    | **0.6262** | **0.3076** | **0.2832**          | **0.1575**            |

# %% [markdown]
# y_gamma = 0.2 :
#
# | Model  | RMSE       | MAE        | P50 q-risk (scaled) | P50 q-risk (unscaled) |
# | ------ | ---------- | ---------- | ------------------- | --------------------- |
# | OLS    | 0.8151     | 0.5295     | 0.4845              | 0.2698                |
# | VAR(1) | 0.7773     | 0.5792     | 0.5299              | 0.2951                |
# | TFT    | **0.6630** | **0.3235** | **0.2960**          | **0.1649**            |
